# %% [markdown]
# # Webscraping

# %%
from requests import get
from bs4 import BeautifulSoup
from html.parser import HTMLParser
from time import sleep

# https://amiunique.org/fingerprint
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"

# %%
base_url = "https://quotes.toscrape.com/page/"

corpus = []

for page in range(1, 10):
    url = base_url + str(page)
    response = get(url, headers={"User-Agent": user_agent})

    soup = BeautifulSoup(
        response.content,
        "html.parser"
    )

    quotes = soup.find_all(
        "div", 
        attrs={"class": "quote"})

    for quote in quotes:
        textquote = quote.find_next("span", attrs={"class": "text"})
        corpus.append(textquote.text)
        # break

    sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 for page in range(1, 10):
#       6     url = base_url + str(page)
# ----> 7     response = get(url, headers={"User-Agent": user_agent})
#       9     soup = BeautifulSoup(
#      10         response.content,
#      11         "html.parser"
#      12     )
#      14     quotes = soup.find_all(
#      15         "div",
#      16         attrs={"class": "quote"})
#
# NameError: name 'get' is not defined

# %%
for index, quote in enumerate(corpus):
    with open(f"output/quote_{index}.txt", "w", encoding="utf-8") as file:
        file.write(quote)
